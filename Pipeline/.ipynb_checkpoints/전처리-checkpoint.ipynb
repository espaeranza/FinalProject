# %%
### import pandas as pd
import numpy as np
import os

# 패키지 임포트
import selenium
from selenium import webdriver
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By # 셀레니움 4.0부터 포함된 함수(필수)
import time
from selenium.webdriver.common.keys import Keys

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from glob import glob

# %%
data = pd.read_csv('./data/products_reviews_total.csv', encoding='utf-8')

# %%
data.tail()
# Out:
#       level_0  index  카테고리1      카테고리2  \
# 1926     95.0  108.0  완구/취미  신생아/영아완구
# 1927     96.0  109.0  완구/취미  신생아/영아완구
# 1928     98.0  111.0  완구/취미  신생아/영아완구
# 1929     99.0  112.0  완구/취미  신생아/영아완구
# 1930    101.0  114.0  완구/취미  신생아/영아완구
#
#                                                카테고리 url  \
# 1926  http://www.coupang.com/np/categories/331793?pa...
# 1927  http://www.coupang.com/np/categories/331793?pa...
# 1928  http://www.coupang.com/np/categories/331793?pa...
# 1929  http://www.coupang.com/np/categories/331793?pa...
# 1930  http://www.coupang.com/np/categories/331793?pa...
#
#                                            제품명  \
# 1926                하베브릭스 유아용 바람개비 아기체육관, 혼합색상
# 1927               러닝리소스 시간학습 활동세트 LER3220, 1개
# 1928                         윈펀 뉴 러닝 테이블, 혼합색상
# 1929  튤립 사운드북 율동 놀이 동요 + 아기 동요 세상 분홍 세트, 스마트베어
# 1930                     인피니펀 스마트 3종 세트, 혼합 색상
#
#                                                  제품 url  리뷰 개수  상품 별점  url2  \
# ...

# %%
data.columns
# Out:
# Index(['카테고리1', '카테고리2', '카테고리 url', '제품명', '제품 url', '리뷰 개수', '상품 별점', '리뷰',
#        '리뷰(좋음)', '리뷰(보통)', '리뷰(별로)'],
#       dtype='object')

# %%
data.drop(data.columns[11:], axis=1, inplace = True)

# %%
data.drop(['level_0', 'index', 'url2'], axis = 1, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1931 entries, 0 to 1930
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   카테고리1     1931 non-null   object
#  1   카테고리2     1931 non-null   object
#  2   카테고리 url  1931 non-null   object
#  3   제품명       1931 non-null   object
#  4   제품 url    1931 non-null   object
#  5   리뷰 개수     1931 non-null   int64
#  6   상품 별점     1931 non-null   float64
#  7   리뷰        1901 non-null   object
#  8   리뷰(좋음)    1931 non-null   object
#  9   리뷰(보통)    1931 non-null   object
#  10  리뷰(별로)    1931 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 166.1+ KB

# %%
data.rename(columns = {'카테고리1' : 'category1'}, inplace = True)

# %%
data.rename(columns = {'카테고리2' : 'category2'}, inplace = True)

# %%
data.rename(columns = {'카테고리 url' : 'category_url'}, inplace = True)

# %%
data.rename(columns = {'제품명' : 'product_name'}, inplace = True)

# %%
data.rename(columns = {'제품 url' : 'product_url'}, inplace = True)

# %%
data.rename(columns = {'리뷰 개수' : 'review_cnt'}, inplace = True)

# %%
data.rename(columns = {'상품 별점' : 'product_rating'}, inplace = True)

# %%
data.rename(columns = {'리뷰' : 'review'}, inplace = True)

# %%
data.rename(columns = {'리뷰(좋음)' : 'review_good'}, inplace = True)

# %%
data.rename(columns = {'리뷰(보통)' : 'review_soso'}, inplace = True)

# %%
data.rename(columns = {'리뷰(별로)' : 'review_bad'}, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1931 entries, 0 to 1930
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category1       1931 non-null   object
#  1   category2       1931 non-null   object
#  2   category_url    1931 non-null   object
#  3   product_name    1931 non-null   object
#  4   product_url     1931 non-null   object
#  5   review_cnt      1931 non-null   int64
#  6   product_rating  1931 non-null   float64
#  7   review          1901 non-null   object
#  8   review_good     1931 non-null   object
#  9   review_soso     1931 non-null   object
#  10  review_bad      1931 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 166.1+ KB

# %%
data.to_csv('./data/data_ver2.csv', encoding = 'utf-8')

# %%
newdata = pd.read_csv('./data/total_data_ver2.csv', encoding = 'utf-8')

# %%
newdata.head()
# Out:
#    Unnamed: 0 category1 category2  \
# 0           0    출산/유아동     수유용품
# 1           1    출산/유아동     수유용품
# 2           2    출산/유아동     수유용품
# 3           3    출산/유아동     수유용품
# 4           4    출산/유아동     수유용품
#
#                                         category_url  \
# 0  http://www.coupang.com/np/categories/221943?pa...
# 1  http://www.coupang.com/np/categories/221943?pa...
# 2  http://www.coupang.com/np/categories/221943?pa...
# 3  http://www.coupang.com/np/categories/221943?pa...
# 4  http://www.coupang.com/np/categories/221943?pa...
#
#                                         product_name  \
# 0            그로미미 PPSU 젖병 트윈팩, 체리쉬(로즈골드), 300ml, 1세트
# 1                 매일유업 앱솔루트 액상분유 니플, M (6~12개월), 5개입
# 2  마더케이 일회용젖병 + 블럭 케이스 + 스크류 2p + 젖병지퍼백 25p 외출 패키...
# 3                       모윰 스마트 분유 보온병 500ml, 베이지, 1개
# 4  모윰 PPSU 올인원 젖병 170ml 2p + 리얼핏 젖꼭지 1단계 2p 세트, 2...
#
#                                          product_url  review_cnt  \
# ...

# %%
newdata.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
newdata.reset_index()
# Out:
#       index category1  category2  \
# 0         0    출산/유아동      수유용품
# 1         1    출산/유아동      수유용품
# 2         2    출산/유아동      수유용품
# 3         3    출산/유아동      수유용품
# 4         4    출산/유아동      수유용품
# ...     ...       ...        ...
# 1926   1926     완구/취미  신생아/영아완구
# 1927   1927     완구/취미  신생아/영아완구
# 1928   1928     완구/취미  신생아/영아완구
# 1929   1929     완구/취미  신생아/영아완구
# 1930   1930     완구/취미  신생아/영아완구
#
#                                            category_url  \
# 0     http://www.coupang.com/np/categories/221943?pa...
# 1     http://www.coupang.com/np/categories/221943?pa...
# 2     http://www.coupang.com/np/categories/221943?pa...
# 3     http://www.coupang.com/np/categories/221943?pa...
# 4     http://www.coupang.com/np/categories/221943?pa...
# ...                                                 ...
# 1926  http://www.coupang.com/np/categories/331793?pa...
# 1927  http://www.coupang.com/np/categories/331793?pa...
# 1928  http://www.coupang.com/np/categories/331793?pa...
# ...

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1931 entries, 0 to 1930
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category1       1931 non-null   object
#  1   category2       1931 non-null   object
#  2   category_url    1931 non-null   object
#  3   product_name    1931 non-null   object
#  4   product_url     1931 non-null   object
#  5   review_cnt      1931 non-null   int64
#  6   product_rating  1931 non-null   float64
#  7   review          1901 non-null   object
#  8   review_good     1931 non-null   object
#  9   review_soso     1931 non-null   object
#  10  review_bad      1931 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 166.1+ KB

# %%
newdata.to_csv('./data/data_ver2.csv', encoding = 'utf-8', index = False)

# %%
ver3 = pd.read_csv('./data/review_final_plus_10.csv', low_memory=False)

# %%
ver3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134713 entries, 0 to 134712
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   index            134713 non-null  int64
#  1   reviewer_name    133717 non-null  object
#  2   userid           134713 non-null  object
#  3   ratings          134713 non-null  int64
#  4   review_contents  134213 non-null  object
#  5   help             80365 non-null   object
#  6   date             133717 non-null  object
#  7   category1        996 non-null     object
#  8   category2        996 non-null     object
#  9   product_name     996 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 10.3+ MB
